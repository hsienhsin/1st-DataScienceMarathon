# %% [markdown]
# 作業目標:<br>
# 1. 熟悉索引與欄位設定
# 2. 使用樞紐建立新資料

# %% [markdown]
# 作業重點:<br>
# 1. 多維度索引、欄位是有順序性的須注意
# 2. 使用樞紐建立資料需要注意參數<br>
#   index : 新資料的索引名稱<br>
#   columns : 新資料的欄位名稱<br>
#   values :新資料的值名稱

# %% [markdown]
# 題目: 運用下列分數資料重新建構資料，將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score<br><br>
# score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
import pandas as pd
import numpy as np
score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])
score_df
# Out:
#     student_id  math_score  english_score  chinese_score   sex  class
# 0            1          50             80             70   boy      1
# 1            2          60             45             50   boy      2
# 2            3          98             43             55   boy      1
# 3            4          70             69             89   boy      2
# 4            5          56             79             60  girl      1
# 5            6          60             68             55  girl      2
# 6            7          45             70             77  girl      1
# 7            8          55             77             76  girl      2
# 8            9          25             57             60  girl      1
# 9           10          88             40             43  girl      3
# 10          11          25             60             45   boy      3
# 11          12          80             60             23   boy      3
# 12          13          20             90             66  girl      3
# 13          14          50             50             50  girl      3
# 14          15          89             67             77  girl      3

# %%
score_df.stack(level=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-b5c2cee038e7> in <module>
# ----> 1 score_df.stack(level=1)
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py in stack(self, level, dropna)
#    6249             return stack_multiple(self, level, dropna=dropna)
#    6250         else:
# -> 6251             return stack(self, level, dropna=dropna)
#    6252
#    6253     def explode(self, column: Union[str, Tuple]) -> "DataFrame":
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in stack(frame, level, dropna)
#     510
#     511     # Will also convert negative level numbers and check if out of bounds.
# --> 512     level_num = frame.columns._get_level_number(level)
#     513
#     514     if isinstance(frame.columns, MultiIndex):
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1418
#    1419     def _get_level_number(self, level):
# -> 1420         self._validate_index_level(level)
#    1421         return 0
#    1422
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1410             elif level > 0:
#    1411                 raise IndexError(
# -> 1412                     f"Too many levels: Index has only 1 level, not {level + 1}"
#    1413                 )
#    1414         elif level != self.name:
#
# IndexError: Too many levels: Index has only 1 level, not 2

# %%
#將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score
score_df.pivot(index='sex', columns=['chinese_score', 'english_score', 'math_score'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f6a1a3c213f9> in <module>
#       1 #將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score
# ----> 2 score_df.pivot(index='sex', columns=['chinese_score', 'english_score', 'math_score'])
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     433         cols = [columns] if index is None else [index, columns]
#     434         append = index is None
# --> 435         indexed = data.set_index(cols, append=append)
#     436     else:
#     437         if index is None:
#
# ~/Anaconda3/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4345                 # ensure_index_from_sequences would not raise for append=False.
#    4346                 raise ValueError(
# -> 4347                     f"Length mismatch: Expected {len(self)} rows, "
#    4348                     f"received array of length {len(arrays[-1])}"
#    4349                 )
#
# ValueError: Length mismatch: Expected 15 rows, received array of length 3

# %%
score_df.melt()
# Out:
#       variable value
# 0   student_id     1
# 1   student_id     2
# 2   student_id     3
# 3   student_id     4
# 4   student_id     5
# ..         ...   ...
# 85       class     3
# 86       class     3
# 87       class     3
# 88       class     3
# 89       class     3
#
# [90 rows x 2 columns]
